# %% [markdown]
# <a href="https://colab.research.google.com/github/irfancheemaa/ICP1/blob/master/ICP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing pandas and seaborn

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# Getting the file path and reading it as CSV

# %%
path = '/content/Data.csv'
df = pd.read_csv(path)

# %% [markdown]
# Will be performing three analysis on the data but first will look at what the columns are and what can be analyzed.

# %%
df.head(20) #will be looking at the first 20 data set
# Out:
#           id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0     842302         M  ...                  0.11890          NaN
# 1     842517         M  ...                  0.08902          NaN
# 2   84300903         M  ...                  0.08758          NaN
# 3   84348301         M  ...                  0.17300          NaN
# 4   84358402         M  ...                  0.07678          NaN
# 5     843786         M  ...                  0.12440          NaN
# 6     844359         M  ...                  0.08368          NaN
# 7   84458202         M  ...                  0.11510          NaN
# 8     844981         M  ...                  0.10720          NaN
# 9   84501001         M  ...                  0.20750          NaN
# 10    845636         M  ...                  0.08452          NaN
# 11  84610002         M  ...                  0.10480          NaN
# 12    846226         M  ...                  0.10230          NaN
# ...

# %%
df.columns #get the columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.info # Information about the dataframe
# Out:
# <bound method DataFrame.info of            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]>

# %%
df['diagnosis'].value_counts() #counting the benign and malignant tumors
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(x = 'diagnosis', hue='diagnosis', data = df)

# %%
import matplotlib.pyplot as plt # imports to plot data
import seaborn as sns
# %config InlineBackend.figure_format = 'retina' #to give better graphics

# %%
df.hist('smoothness_mean')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f01b2396278>]],
#       dtype=object)

# %%
#averag line to a histogram and make a point in the plot which seems important. For this case just picked a random point
x = df.area_mean.plot()
x.axhline(1500, color="red", linestyle="--")
x.axvline(200, color="red", linestyle="--")

# %%
df.radius_mean.hist(bins=30, cumulative=True) #cumulative number of observation set to 30
