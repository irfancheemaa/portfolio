# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re

from sklearn.preprocessing import LabelEncoder

# %%
# load data and keeping the needed data columns 
data = pd.read_csv('/content/Sentiment.csv')
data = data[['text', 'sentiment']]
data.head(5) # looking at the data
# Out:
#                                                 text sentiment
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive

# %%
data['text'] = data['text'].apply(lambda x: x.lower()) # lowercase text
data['text'] = data['text'].apply((lambda x: re.sub('[^a-zA-z0-9\s]', '', x)))

for idx, row in data.iterrows(): # iterate through the data and replace the rows with rt with ' ' 
  row[0] = row[0].replace('rt', ' ')

# %%
max_features = 2000 # creating max feauture variable 
tokenizer = Tokenizer(num_words=max_features, split=' ') #passing in the number of max features and splitting the data

 # getting the values fitting the tokenizer 
tokenizer.fit_on_texts(data['text'].values) 
X = tokenizer.texts_to_sequences(data['text'].values) 
X = pad_sequences(X)

# %%
embed_dim = 128 # embedding dimensions
lstm_out = 196 # lst output
# model created
def createmodel():
    model = Sequential()
    model.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
    model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(3,activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    model.save('model.h5') # saving the model 

    return model

model_sum = createmodel()
model_sum.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 28, 128)           256000
# _________________________________________________________________
# lstm (LSTM)                  (None, 196)               254800
# _________________________________________________________________
# dense (Dense)                (None, 3)                 591
# =================================================================
# Total params: 511,391
# Trainable params: 511,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# label encoding the senteiment columns 
labelencoder = LabelEncoder() 
integer_encoded = labelencoder.fit_transform(data['sentiment'])
y = to_categorical(integer_encoded)
X_train, X_test, Y_train, Y_test = train_test_split(X,y, test_size = 0.33, random_state = 42) # traning the data with test size of 0.33

# compiling the model 
batch_size = 32
model = createmodel()
model.fit(X_train, Y_train, epochs = 1, batch_size=batch_size, verbose = 2)
score,acc = model.evaluate(X_test,Y_test,verbose=2,batch_size=batch_size)
# looking at the score
print(score)
print(acc)
print(model.metrics_names)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 291/291 - 33s - loss: 0.8224 - accuracy: 0.6458
# 144/144 - 1s - loss: 0.7809 - accuracy: 0.6737
# 0.7808601260185242
# 0.6736566424369812
# ['loss', 'accuracy']

# %%
from keras.wrappers.scikit_learn import KerasClassifier

model_2 = KerasClassifier(build_fn=createmodel, verbose=1)
batch_size = [10, 20, 40]
epochs = [1, 2, 3]
param_grid = dict (batch_size=batch_size, epochs=epochs)
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator=model_2, param_grid=param_grid)
grid_result = grid.fit(X_train, Y_train)

print("Best: %f using %s"%(grid_result.best_score_, grid_result.best_params_))
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 744/744 [==============================] - 85s 112ms/step - loss: 0.8856 - accuracy: 0.6278
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7584 - accuracy: 0.6627
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 744/744 [==============================] - 86s 113ms/step - loss: 0.8784 - accuracy: 0.6226
# 186/186 [==============================] - 2s 8ms/step - loss: 0.7590 - accuracy: 0.6713
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 744/744 [==============================] - 83s 109ms/step - loss: 0.8736 - accuracy: 0.6234
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7935 - accuracy: 0.6622
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 744/744 [==============================] - 86s 112ms/step - loss: 0.8826 - accuracy: 0.6246
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7647 - accuracy: 0.6706
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 744/744 [==============================] - 84s 110ms/step - loss: 0.8764 - accuracy: 0.6193
# 186/186 [==============================] - 2s 8ms/step - loss: 0.7752 - accuracy: 0.6690
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 744/744 [==============================] - 84s 110ms/step - loss: 0.8790 - accuracy: 0.6247
# Epoch 2/2
# 744/744 [==============================] - 83s 111ms/step - loss: 0.6796 - accuracy: 0.7148
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7238 - accuracy: 0.6799
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 744/744 [==============================] - 86s 113ms/step - loss: 0.8758 - accuracy: 0.6277
# Epoch 2/2
# 744/744 [==============================] - 84s 113ms/step - loss: 0.6785 - accuracy: 0.7207
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7370 - accuracy: 0.6826
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 744/744 [==============================] - 83s 109ms/step - loss: 0.8836 - accuracy: 0.6209
# Epoch 2/2
# 744/744 [==============================] - 81s 109ms/step - loss: 0.6819 - accuracy: 0.7135
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7659 - accuracy: 0.6703
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 744/744 [==============================] - 85s 110ms/step - loss: 0.8828 - accuracy: 0.6215
# Epoch 2/2
# 744/744 [==============================] - 82s 110ms/step - loss: 0.6769 - accuracy: 0.7118
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7630 - accuracy: 0.6636
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 744/744 [==============================] - 83s 109ms/step - loss: 0.8706 - accuracy: 0.6249
# Epoch 2/2
# 744/744 [==============================] - 83s 111ms/step - loss: 0.6547 - accuracy: 0.7273
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7930 - accuracy: 0.6561
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 744/744 [==============================] - 87s 114ms/step - loss: 0.8822 - accuracy: 0.6240
# Epoch 2/3
# 744/744 [==============================] - 82s 111ms/step - loss: 0.6831 - accuracy: 0.7117
# Epoch 3/3
# 744/744 [==============================] - 84s 112ms/step - loss: 0.5858 - accuracy: 0.7573
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7587 - accuracy: 0.6826
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 744/744 [==============================] - 85s 111ms/step - loss: 0.8720 - accuracy: 0.6314
# Epoch 2/3
# 744/744 [==============================] - 82s 110ms/step - loss: 0.6800 - accuracy: 0.7086
# Epoch 3/3
# 744/744 [==============================] - 82s 110ms/step - loss: 0.5935 - accuracy: 0.7596
# 186/186 [==============================] - 2s 8ms/step - loss: 0.7667 - accuracy: 0.6810
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 744/744 [==============================] - 85s 112ms/step - loss: 0.8727 - accuracy: 0.6322
# Epoch 2/3
# 744/744 [==============================] - 83s 112ms/step - loss: 0.6707 - accuracy: 0.7227
# Epoch 3/3
# 744/744 [==============================] - 82s 111ms/step - loss: 0.5762 - accuracy: 0.7628
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7823 - accuracy: 0.6864
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 744/744 [==============================] - 84s 110ms/step - loss: 0.8783 - accuracy: 0.6308
# Epoch 2/3
# 744/744 [==============================] - 82s 110ms/step - loss: 0.6902 - accuracy: 0.7093
# Epoch 3/3
# 744/744 [==============================] - 82s 110ms/step - loss: 0.5696 - accuracy: 0.7721
# 186/186 [==============================] - 2s 9ms/step - loss: 0.7627 - accuracy: 0.6781
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 744/744 [==============================] - 84s 110ms/step - loss: 0.8709 - accuracy: 0.6298
# Epoch 2/3
# 744/744 [==============================] - 82s 110ms/step - loss: 0.6605 - accuracy: 0.7195
# Epoch 3/3
# 744/744 [==============================] - 82s 111ms/step - loss: 0.5635 - accuracy: 0.7660
# 186/186 [==============================] - 2s 8ms/step - loss: 0.8138 - accuracy: 0.6615
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 372/372 [==============================] - 43s 109ms/step - loss: 0.8926 - accuracy: 0.6151
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7478 - accuracy: 0.6697
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 372/372 [==============================] - 43s 109ms/step - loss: 0.8902 - accuracy: 0.6220
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7726 - accuracy: 0.6729
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 372/372 [==============================] - 43s 110ms/step - loss: 0.9012 - accuracy: 0.6197
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7508 - accuracy: 0.6762
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 372/372 [==============================] - 43s 109ms/step - loss: 0.8897 - accuracy: 0.6260
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7400 - accuracy: 0.6808
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 372/372 [==============================] - 42s 109ms/step - loss: 0.8904 - accuracy: 0.6210
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7701 - accuracy: 0.6744
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 372/372 [==============================] - 44s 112ms/step - loss: 0.9067 - accuracy: 0.6173
# Epoch 2/2
# 372/372 [==============================] - 42s 112ms/step - loss: 0.6839 - accuracy: 0.7177
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7300 - accuracy: 0.6832
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 372/372 [==============================] - 43s 111ms/step - loss: 0.8877 - accuracy: 0.6172
# Epoch 2/2
# 372/372 [==============================] - 41s 111ms/step - loss: 0.6861 - accuracy: 0.7047
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7444 - accuracy: 0.6859
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 372/372 [==============================] - 42s 108ms/step - loss: 0.8890 - accuracy: 0.6168
# Epoch 2/2
# 372/372 [==============================] - 40s 108ms/step - loss: 0.6645 - accuracy: 0.7156
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7486 - accuracy: 0.6912
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 372/372 [==============================] - 43s 110ms/step - loss: 0.8890 - accuracy: 0.6249
# Epoch 2/2
# 372/372 [==============================] - 41s 110ms/step - loss: 0.6854 - accuracy: 0.7112
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7368 - accuracy: 0.6744
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 372/372 [==============================] - 43s 111ms/step - loss: 0.8888 - accuracy: 0.6179
# Epoch 2/2
# 372/372 [==============================] - 42s 112ms/step - loss: 0.6733 - accuracy: 0.7189
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7743 - accuracy: 0.6728
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 372/372 [==============================] - 43s 109ms/step - loss: 0.8840 - accuracy: 0.6237
# Epoch 2/3
# 372/372 [==============================] - 40s 108ms/step - loss: 0.6760 - accuracy: 0.7163
# Epoch 3/3
# 372/372 [==============================] - 41s 109ms/step - loss: 0.5971 - accuracy: 0.7501
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7362 - accuracy: 0.6853
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 372/372 [==============================] - 42s 108ms/step - loss: 0.8695 - accuracy: 0.6264
# Epoch 2/3
# 372/372 [==============================] - 41s 109ms/step - loss: 0.6707 - accuracy: 0.7179
# Epoch 3/3
# 372/372 [==============================] - 40s 109ms/step - loss: 0.6022 - accuracy: 0.7480
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7508 - accuracy: 0.6703
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 372/372 [==============================] - 43s 109ms/step - loss: 0.8961 - accuracy: 0.6162
# Epoch 2/3
# 372/372 [==============================] - 41s 111ms/step - loss: 0.6855 - accuracy: 0.7134
# Epoch 3/3
# 372/372 [==============================] - 40s 109ms/step - loss: 0.5988 - accuracy: 0.7449
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7648 - accuracy: 0.6875
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 372/372 [==============================] - 43s 110ms/step - loss: 0.8928 - accuracy: 0.6217
# Epoch 2/3
# 372/372 [==============================] - 41s 111ms/step - loss: 0.6771 - accuracy: 0.7151
# Epoch 3/3
# 372/372 [==============================] - 41s 111ms/step - loss: 0.5940 - accuracy: 0.7503
# 93/93 [==============================] - 1s 9ms/step - loss: 0.7655 - accuracy: 0.6760
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 372/372 [==============================] - 43s 110ms/step - loss: 0.8950 - accuracy: 0.6206
# Epoch 2/3
# 372/372 [==============================] - 41s 110ms/step - loss: 0.6653 - accuracy: 0.7169
# Epoch 3/3
# 372/372 [==============================] - 42s 112ms/step - loss: 0.5720 - accuracy: 0.7640
# 93/93 [==============================] - 1s 9ms/step - loss: 0.8269 - accuracy: 0.6636
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 186/186 [==============================] - 23s 111ms/step - loss: 0.9267 - accuracy: 0.6018
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7557 - accuracy: 0.6708
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 186/186 [==============================] - 24s 116ms/step - loss: 0.9263 - accuracy: 0.6150
# 47/47 [==============================] - 1s 10ms/step - loss: 0.8012 - accuracy: 0.6600
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 186/186 [==============================] - 23s 110ms/step - loss: 0.9065 - accuracy: 0.6080
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7636 - accuracy: 0.6756
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 186/186 [==============================] - 23s 110ms/step - loss: 0.9101 - accuracy: 0.6116
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7507 - accuracy: 0.6733
# WARNING:tensorflow:Layer lstm_37 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 186/186 [==============================] - 23s 112ms/step - loss: 0.9131 - accuracy: 0.6087
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7898 - accuracy: 0.6539
# WARNING:tensorflow:Layer lstm_38 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 186/186 [==============================] - 23s 111ms/step - loss: 0.9104 - accuracy: 0.6165
# Epoch 2/2
# 186/186 [==============================] - 20s 109ms/step - loss: 0.7157 - accuracy: 0.6919
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7292 - accuracy: 0.6880
# WARNING:tensorflow:Layer lstm_39 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 186/186 [==============================] - 23s 110ms/step - loss: 0.9003 - accuracy: 0.6149
# Epoch 2/2
# 186/186 [==============================] - 21s 110ms/step - loss: 0.6884 - accuracy: 0.7102
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7420 - accuracy: 0.6789
# WARNING:tensorflow:Layer lstm_40 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 186/186 [==============================] - 23s 112ms/step - loss: 0.9064 - accuracy: 0.6189
# Epoch 2/2
# 186/186 [==============================] - 21s 113ms/step - loss: 0.6969 - accuracy: 0.7018
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7498 - accuracy: 0.6918
# WARNING:tensorflow:Layer lstm_41 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 186/186 [==============================] - 23s 110ms/step - loss: 0.9017 - accuracy: 0.6167
# Epoch 2/2
# 186/186 [==============================] - 21s 113ms/step - loss: 0.6931 - accuracy: 0.7001
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7406 - accuracy: 0.6803
# WARNING:tensorflow:Layer lstm_42 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 186/186 [==============================] - 23s 112ms/step - loss: 0.9051 - accuracy: 0.6036
# Epoch 2/2
# 186/186 [==============================] - 21s 113ms/step - loss: 0.6993 - accuracy: 0.7005
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7837 - accuracy: 0.6733
# WARNING:tensorflow:Layer lstm_43 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 186/186 [==============================] - 23s 112ms/step - loss: 0.9098 - accuracy: 0.6103
# Epoch 2/3
# 186/186 [==============================] - 21s 112ms/step - loss: 0.6843 - accuracy: 0.7106
# Epoch 3/3
# 186/186 [==============================] - 21s 113ms/step - loss: 0.5988 - accuracy: 0.7524
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7353 - accuracy: 0.6810
# WARNING:tensorflow:Layer lstm_44 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 186/186 [==============================] - 23s 112ms/step - loss: 0.9143 - accuracy: 0.6133
# Epoch 2/3
# 186/186 [==============================] - 21s 111ms/step - loss: 0.6845 - accuracy: 0.7041
# Epoch 3/3
# 186/186 [==============================] - 22s 116ms/step - loss: 0.5978 - accuracy: 0.7564
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7442 - accuracy: 0.6789
# WARNING:tensorflow:Layer lstm_45 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 186/186 [==============================] - 24s 116ms/step - loss: 0.9126 - accuracy: 0.6093
# Epoch 2/3
# 186/186 [==============================] - 21s 115ms/step - loss: 0.6887 - accuracy: 0.6998
# Epoch 3/3
# 186/186 [==============================] - 21s 114ms/step - loss: 0.5983 - accuracy: 0.7519
# 47/47 [==============================] - 1s 11ms/step - loss: 0.7552 - accuracy: 0.6832
# WARNING:tensorflow:Layer lstm_46 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 186/186 [==============================] - 24s 118ms/step - loss: 0.9191 - accuracy: 0.6087
# Epoch 2/3
# 186/186 [==============================] - 21s 115ms/step - loss: 0.6928 - accuracy: 0.7033
# Epoch 3/3
# 186/186 [==============================] - 22s 120ms/step - loss: 0.5935 - accuracy: 0.7448
# 47/47 [==============================] - 1s 10ms/step - loss: 0.7621 - accuracy: 0.6781
# WARNING:tensorflow:Layer lstm_47 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/3
# 186/186 [==============================] - 24s 115ms/step - loss: 0.9049 - accuracy: 0.6195
# Epoch 2/3
# 186/186 [==============================] - 22s 116ms/step - loss: 0.6819 - accuracy: 0.7097
# Epoch 3/3
# 186/186 [==============================] - 22s 118ms/step - loss: 0.5857 - accuracy: 0.7583
# 47/47 [==============================] - 1s 10ms/step - loss: 0.8023 - accuracy: 0.6658
# WARNING:tensorflow:Layer lstm_48 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/2
# 233/233 [==============================] - 29s 118ms/step - loss: 0.8928 - accuracy: 0.6137
# Epoch 2/2
# 233/233 [==============================] - 28s 118ms/step - loss: 0.6801 - accuracy: 0.7035
# Best: 0.682448 using {'batch_size': 40, 'epochs': 2}
